# %%
import numpy as np
import pandas as pd
import os
import math
import random
import shutil
from PIL import Image
import skimage
from skimage.io import imread
from skimage.metrics import structural_similarity as ssim
from skimage.color import rgb2gray

# %%
path=r'C:\Users\Biswarup Mistry\Desktop\USC_SIPI_Databases' #USC_SIPI_Database directory [To Change 1]
dir_list=os.listdir(path)
print(len(dir_list))
# Out:
# 4

# %%
directory = "Training Set"
directory1 = "Test Set"

# %%
for item in dir_list :
    if item != "misc" :
        p=str(path+'\\'+str(item))
        dir_lst=os.listdir(p)
        #a=random.choices(dir_lst, k=3)  #Choose multiple random items from a list, set, or any data structure.
        i=1
        cal=math.floor((len(dir_lst)*80)/100)
        cal1=len(dir_lst)-cal
        #directory = "Training Set"
        parent_dir = p
        path1 = os.path.join(parent_dir, directory)
        os.mkdir(path1) #making the 'Training Set' Directory
        new_path=str(parent_dir+'\\'+directory)
        
        while i<=cal :
            a=random.choices(os.listdir(p)) #randomly choosen 80% training data set of current dataset & gives a list
            for image in a :
                if image != directory :
                    old_path=p+'\\'+image
                    n_path=new_path+'\\'+image
                    #try :
                    shutil.move(old_path, n_path) #to move the files
                    #except FileNotFoundError :
                        #print('Error : File not Found for Image = ',image)
                    i+=1
       
        #directory1 = "Test Set"
        parent_dir = p
        path1 = os.path.join(parent_dir, directory1)
        os.mkdir(path1) #making the 'Training Set' Directory
        new_path=str(parent_dir+'\\'+directory1)
        a=os.listdir(p)
        for item in a:
            if (item != directory) and (item != directory1) :
                old_path=p+'\\'+item
                n_path=new_path+'\\'+item
                shutil.move(old_path, n_path)

# %%
def get_Noise(image, prob):
    #'''
    #Add salt and pepper noise to image
    #prob: Probability of the noise
    #'''
    output = image.copy()
    if len(image.shape) == 2:
        black = 0
        white = 255            
    else:
        colorspace = image.shape[2]
        if colorspace == 3:  # RGB
            black = np.array([0, 0, 0], dtype='uint8')
            white = np.array([255, 255, 255], dtype='uint8')
        else:  # RGBA
            black = np.array([0, 0, 0, 255], dtype='uint8')
            white = np.array([255, 255, 255, 255], dtype='uint8')
    probs = np.random.random(output.shape[:2])
    output[probs < (prob / 2)] = black
    output[probs > 1 - (prob / 2)] = white
    return output

# %%
def SSIMVsNoiseDensity(dirc_list,dataframe): #getting corresponding mse(s) for given noise density 'd'
    r=255.0
    #dataframe = pd.DataFrame()
    for item in os.listdir(dirc_list) :
        #k=str(path+str(item))
        k=str(dirc_list+'\\'+item)
        img = imread(k)
        #x=[]
        #y=[]
        df=np.array([])
        #i=iteration
        d=0.1
        #while(i>0 and d<=0.3):
        D=[0.1,0.2,0.3]
        for d in D:
            #img=np.squeeze(img)
            
            
            
            noise_img=get_Noise(img,d) #getting noisy image
            
            #---------------------- (conversion for SSIM)
            if len(img.shape)!=2 : #if image is not gray, i.e., RGB
                im = rgb2gray(img)
                noise_im=rgb2gray(noise_img)
            else : #if image is Gray already
                im=img
                noise_im=noise_img
            #---------------------- (conversion for SSIM)
            
            SSIM = ssim(im,noise_im) #Obtaining the value of SSIM b/t two Images(Noisy and Original)
            
            #x.append(d)
            #y.append(SSIM)
            df=np.append(df,SSIM)
        dataframe[item] = df

# %%
dataframe = pd.DataFrame()
for item in dir_list :
    if item != "misc" :
        p=str(path+'\\'+str(item))
        dir_lst=os.listdir(p)
        for item in dir_lst:
            if item != directory1:
                new_path=str(p+'\\'+str(item))
                SSIMVsNoiseDensity(new_path,dataframe)
                #for item in os.listdir(new_path): #under Training Set
                #    k=str(new_path+'\\'+str(item))
                #    getPSNR(image)
dataframe.to_csv('SSIM_of_80_percent_Data.csv', index=False)   
        #print(dir_lst)
# Out:
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df
# C:\Users\Biswarup Mistry\AppData\Local\Temp\ipykernel_12468\2175632644.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataframe[item] = df

# %%
data=pd.read_csv('SSIM_of_80_percent_Data.csv')
data
# Out:
#    2.1.01.tiff  2.1.02.tiff  2.1.03.tiff  2.1.04.tiff  2.1.06.tiff  \
# 0     0.394695     0.473075     0.224899     0.367832     0.370970
# 1     0.228307     0.297954     0.117425     0.202340     0.209373
# 2     0.150455     0.205669     0.077722     0.131611     0.140345
#
#    2.1.08.tiff  2.1.09.tiff  2.1.11.tiff  2.1.12.tiff  2.2.01.tiff  ...  \
# 0     0.237075     0.206567     0.301607     0.270964     0.375711  ...
# 1     0.113316     0.100838     0.164268     0.134104     0.217817  ...
# 2     0.071457     0.065976     0.107167     0.085707     0.145297  ...
#
#    1.4.11.tiff  1.4.12.tiff  1.5.05.tiff  1.5.06.tiff  1.5.07.tiff  \
# 0     0.408350     0.362822     0.246547     0.112909     0.354542
# 1     0.229793     0.199534     0.126597     0.047846     0.191064
# 2     0.151261     0.125955     0.082547     0.028801     0.123296
#
#    texmos1.p512.tiff  texmos2.p512.tiff  texmos2.s512.tiff  texmos3.s512.tiff  \
# 0           0.753250           0.757610           0.146665           0.105690
# 1           0.583581           0.586081           0.080835           0.047105
# 2           0.453943           0.459312           0.058364           0.032212
#
#    texmos3b.p512.tiff
# 0            0.747728
# 1            0.573278
# 2            0.441491
#
# [3 rows x 136 columns]
