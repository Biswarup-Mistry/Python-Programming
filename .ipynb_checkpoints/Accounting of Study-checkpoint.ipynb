# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#data=pd.read_csv('C:\\Users\\Biswarup Mistry\\Desktop\\Accounting of Goal  - Sheet1 (1).csv') #in windows
data=pd.read_csv('/home/biswarup/Desktop/Accounting of Goal  - Sheet1 (1).csv' ) #in ubuntu
#data

# %%
def Truth():
    m=data['Hours']
    #print('m= ', m)
    x=[]
    i=0
    x=m.dropna()
    #print('x=',x)
    #print('len(x)=',len(x))
    #len(y)=len(x)
    y=[None]*len(x)
    while i<len(x):
        y[i]=i
        i+=1
    #print('y=',y)
    plt.plot(y,x)
    plt.show()
    i=0
    count=0
    max=0
    while i<len(x):
        if x[i]!=0:
            count+=1
            if max<x[i]:
                max=x[i]
        i+=1
    print('(i). Total Day of Studing : ',count,'/',len(x))
    p=count/len(x)
    print('(ii). Probability of Success : ', p*100,' %')
    print('(iii). Highest hour of study : ',max,' Hour(s)')

# %%
Truth()
# Out:
# (i). Total Day of Studing :  66 / 308
# (ii). Probability of Success :  21.428571428571427  %
# (iii). Highest hour of study :  11.5  Hour(s)
