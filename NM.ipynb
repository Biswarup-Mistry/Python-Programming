# %%
#from SSIM_PIL import compare_ssim
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd

import skimage
from skimage.io import imread
import os

import csv

# %%
def get_Noise(img,d):
    return skimage.util.random_noise(img, mode='s&p', amount=d)

# %%
def creatingCsvFile(dir_list):    
    #i=0
    p=[]
    f = open('MSE(s)ofImages.csv', "a") 
    #while i<6:
    #    p.append(i)
    #    i+=1
    #f.write(str(p))
    #f.write('\n')
    
    #for item in dir_list:
    f.write('density/Item')
    i=0
    while i<20:
        f.write('d'+str(i)+'\n')
        i+=1
    f.close()
    #df=pd.read_csv('MSE(s)ofImages.csv')
    #df = pd.DataFrame(columns=[dir_list])
    #df.to_csv("MSE(s)ofImages.csv")
    
    #df= pd.read_csv('MSE(s)ofImages.csv')                           # Read CSV file
    #df = pd.DataFrame(columns=[item])
    #df[item] = y
    #df.to_csv("MSE(s)ofImages.csv")

# %%
#path='C://Users//Biswarup Mistry//Desktop//Misc//'
#dir_list = os.listdir(path)
 
#print("Files and directories in '", path, "' :")
 
# prints all files
#print(dir_list)
#print('\n')

# %%
def mseplotting(img,item):
    i=20
    x=[]
    y=[]
    d=0.0
    while(i>0 and d<=1.0):
        noise_img=get_Noise(img,d) #getting noisy image

        mse=np.square(np.subtract(img,noise_img)).mean() #calculating MSE of Original image and Image with Noise
        #print('MSE : ',mse)
        x.append(d)
        y.append(mse)
        d=d+0.05 #d runs for 20 times
        
        
        
        
        
        #f = open('MSE(s)ofImages.csv', "a") 
        #f.write(str(mse)+'\n')
        #f.close()
        i=i-1

    plt.title('MSE VS Density of Noise of Image : '+item)
    plt.xlabel("Density")
    plt.ylabel("MSE")
    #plt.scatter(x, y)

    plt.plot(x, y, marker='o')
    #plt.twinx()
    plt.show()  #need to be turned on-------
    
    #f = open('MSE(s)ofImages.csv', "a") 
    #f.write(str(y))
    #f.write('\n')
    #f.close()
    
    
      
    
    
    
    
    df= pd.read_csv('MSE(s)ofImages.csv')                           # Read CSV file
    df = pd.DataFrame(columns=['density/Item'])
    #df.insert(loc=item,column=item value=y)
    #df.to_csv("MSE(s)ofImages.csv")
    
    df.insert(loc=len(df.columns),                       # Where to insert
             column=item,                        # Name of new column
             value=y)
    
    
    #df = df.assign(item = y) # New column
                       #new_4 = mtcars.mpg ＞ 30) # Another new column
    df.to_csv("MSE(s)ofImages.csv")

# %%
path='C://Users//Biswarup Mistry//Desktop//Misc//'  #defining the image directory
dir_list = os.listdir(path)

# %%
creatingCsvFile(dir_list)

# %%
#print("Files and directories in '", path, "' :")
 
# prints all files
#print(dir_list)
#print('\n')

for item in dir_list :
    k=str(path+str(item))
    img = imread(k)
    #plt.title('Original Image')
    plt.imshow(img,cmap=plt.cm.gray)
    plt.show()

for item in dir_list :
    k=str(path+str(item))
    img = imread(k)
    mseplotting(img,item)

# %%
data=pd.read_csv(r"C:\Users\Biswarup Mistry\Desktop\The_Files\CODING\Python-Programming\MSE(s)ofImages.csv")
data
# Out:
#     Unnamed: 0  density/Item        6.tiff
# 0            0           NaN  16958.117554
# 1            1           NaN  16958.625161
# 2            2           NaN  16958.946114
# 3            3           NaN  16959.085396
# 4            4           NaN  16959.404202
# 5            5           NaN  16959.909735
# 6            6           NaN  16960.272842
# 7            7           NaN  16960.717586
# 8            8           NaN  16960.803617
# 9            9           NaN  16961.239093
# 10          10           NaN  16961.116331
# 11          11           NaN  16961.840975
# 12          12           NaN  16961.835633
# 13          13           NaN  16961.906661
# 14          14           NaN  16962.936754
# 15          15           NaN  16962.985003
# 16          16           NaN  16962.924720
# 17          17           NaN  16963.674318
# 18          18           NaN  16964.270499
# 19          19           NaN  16964.253615

# %%
#I2=np.array(reshape(height2, width2))


a=[] #X level
#b=np.array([]) #y level
b=[]

df = pd.DataFrame(data)
j=0
i=20
d=0.0
while i>0:
    d=d+0.05
    a.append(d)
    i-=1
print('len(a) : ',len(a))
while j<6:
    #b=np.append(b,df.iloc[j])
    b.append(df.iloc[j])
    #plt.plot(a,b,marker='o')
    #plt.show()
    j+=1
#print('len(b) : ',len(b))
#print('b : ',b)
    
#print(b)
i=0
c=[]
while i<6:
    c.append(b[i])
    #plt.scatter(a,c,marker='o')   
    #plt.show()
    #print(c)
    i+=1
print('len(c) : ',len(c))

f=0
g=0
while f<6:

    m=[]
    m.append(b[f])
    #print('m : ',m)
    #print('len(m) : ',len(m))
    
    n=[]
    i=0
    #while i<20:
    n.append(m[0:20])
        #i+=1
    print('n : ',n)
    #print('a : ',a)
    #print('m[20] : ',m[19])

    plt.twinx()
    plt.plot(a,n[:])
    #plt.plot(a,n)#,marker='o')
    f+=1
#plt.legend()
plt.show()


#i=0
#k=[] #act as a temproray y axis
#while i<6:
#    k=b[i]
#    plt.plot(a,k,marker='o')
#    plt.show()
#    i+=1


# In[ ]:


#db = np.vstack([b]).T
#print (db[:100])


# In[25]:


i=0
j=0
n=[]
while i<6:
    i+=1

n.append(df.iloc[5])
plt.scatter(a,n)
plt.show()


# In[ ]:
