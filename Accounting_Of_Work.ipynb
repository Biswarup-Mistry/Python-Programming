# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Selecting destination file path

# %%
data=pd.read_csv(r'/home/biswarup/Desktop/Accounting_of_Work .xlsx - Sheet1.csv')    #for linux
#data=pd.read_csv(r'C:\Users\Biswarup\Desktop\Accounting_of_Work .xlsx - Sheet1.csv')    #for windows
data.head(10)   #for testing
#df=pd.DataFrame(data, columns=['x','y'])
# Out:
#        Date  Hours
# 0  15-04-24    0.0
# 1  16-04-24    0.5
# 2  17-04-24    0.5
# 3  18-04-24    0.5
# 4  19-04-24    0.0
# 5  20-04-24    1.0
# 6  21-04-24    1.0
# 7  22-04-24    0.0
# 8  23-04-24    0.0
# 9  24-04-24    0.0

# %% [markdown]
# # Fetching the datas

# %%
df=pd.DataFrame(data, columns=['Hours'])
print(df.head(10))
# Out:
#    Hours
# 0    0.0
# 1    0.5
# 2    0.5
# 3    0.5
# 4    0.0
# 5    1.0
# 6    1.0
# 7    0.0
# 8    0.0
# 9    0.0

# %% [markdown]
# # Marking the X & Y

# %%
y=[]
x=[]
i=0
for i in range(len(df)):
    y.append(df['Hours'][i])
print(len(y))
i=0
for i in range(len(y)):
    x.append(i)
print(len(x))
# Out:
# 630
# 630

# %% [markdown]
# # Making Visual Data

# %%
plt.title('Day(s) vs Hour(s)')
plt.xlabel('Day(s)')
plt.ylabel('Hour(s)')
plt.plot(x,y)
plt.savefig("/home/biswarup/Downloads/output.png") #for linux
#plt.savefig(r"C:\Users\Biswarup\Downloads\output.png")  # for windows
#C:\Users\Biswarup\Downloads\output.png
plt.show()
