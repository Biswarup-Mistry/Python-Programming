# %%
import matplotlib.pyplot as plt
import numpy as np
import random

k=[]
l=[]

ran=int(random.randrange(0,100,1))
print('ran : ',ran)
x=np.array(random.sample(range(100), ran))
y=np.array(random.sample(range(100), ran))

print('x : ',x)
print('y : ',y)


#i=0
#while i<ran:
#    num=10*x[i]+7
#    l.append(num)
#    i+=1
#y=np.array(l)

data = np.vstack([x, y]).T
print (data[:])


plt.xlabel("Avg Pulse")
plt.ylabel("Avg Life")
plt.scatter(x, y,marker='+')
#plt.show()

a=np.sum(x)
b=np.sum(y)

p=[]
i=0
while i<ran:
    p.append(x[i]*y[i])
    i+=1
print('x[i]*y[i] :',p)
c=np.sum(p)

i=0
u=[]
while i<ran:
    u.append(x[i]*x[i])
    i+=1
print('x[i]*x[i] :',u)
d=np.sum(u)

print('sum of array xi^2 : ',d)
print('sum of array xi*yi : ',c)
print('sum of array x :',a, '\nsum of array y :',b)

m=a
n=b
v=c
r=d

z=(m*n-ran*v)/(m*m-ran*r)
s=(m*v-n*r)/(m*m-ran*r)

print("z : ",z,"\ns : ",s)
print('formula is : \n')
print('y = ',z,'x + ',s)

i=0
g=[]
while i<ran:
    g.append(z*x[i]+s)
    i+=1

data = np.vstack([x, g]).T
print (data[:])
    

plt.xlabel("Avg Pulse")
plt.ylabel("Avg Life")
plt.plot(x, g, marker='o')
plt.show()
# Out:
# ran :  34
# x :  [15 98 49 12 67 68  6 28 59 30 18 97 47 42 78 61  8 84 65 93 90 63 72 33
#  44 51 66 80 89 87 81 92 91 20]
# y :  [75 89 61 25 35 51 60 66 12 81 17 99 87 79 22 32 29 48 52 31 37  8 10 72
#  19  9 39 53 27 63 76 15 77  3]
# [[15 75]
#  [98 89]
#  [49 61]
#  [12 25]
#  [67 35]
#  [68 51]
#  [ 6 60]
#  [28 66]
#  [59 12]
#  [30 81]
#  [18 17]
#  [97 99]
#  [47 87]
#  [42 79]
#  [78 22]
#  [61 32]
#  [ 8 29]
#  [84 48]
#  [65 52]
#  [93 31]
#  [90 37]
#  [63  8]
#  [72 10]
#  [33 72]
#  [44 19]
#  [51  9]
#  [66 39]
#  [80 53]
#  [89 27]
#  [87 63]
#  [81 76]
#  [92 15]
#  [91 77]
#  [20  3]]
# x[i]*y[i] : [1125, 8722, 2989, 300, 2345, 3468, 360, 1848, 708, 2430, 306, 9603, 4089, 3318, 1716, 1952, 232, 4032, 3380, 2883, 3330, 504, 720, 2376, 836, 459, 2574, 4240, 2403, 5481, 6156, 1380, 7007, 60]
# x[i]*x[i] : [225, 9604, 2401, 144, 4489, 4624, 36, 784, 3481, 900, 324, 9409, 2209, 1764, 6084, 3721, 64, 7056, 4225, 8649, 8100, 3969, 5184, 1089, 1936, 2601, 4356, 6400, 7921, 7569, 6561, 8464, 8281, 400]
# sum of array xi^2 :  143024
# sum of array xi*yi :  93332
# sum of array x : 1984
# sum of array y : 1559
# z :  0.08659126230357451
# s :  40.80008634087377
# formula is :
#
# y =  0.08659126230357451 x +  40.80008634087377
# [[15.         42.09895528]
#  [98.         49.28603005]
#  [49.         45.04305819]
#  [12.         41.83918149]
#  [67.         46.60170092]
#  [68.         46.68829218]
#  [ 6.         41.31963391]
#  [28.         43.22464169]
#  [59.         45.90897082]
#  [30.         43.39782421]
#  [18.         42.35872906]
#  [97.         49.19943878]
#  [47.         44.86987567]
#  [42.         44.43691936]
#  [78.         47.5542048 ]
#  [61.         46.08215334]
#  [ 8.         41.49281644]
#  [84.         48.07375237]
#  [65.         46.42851839]
#  [93.         48.85307374]
#  [90.         48.59329995]
#  [63.         46.25533587]
#  [72.         47.03465723]
#  [33.         43.657598  ]
#  [44.         44.61010188]
#  [51.         45.21624072]
#  [66.         46.51510965]
#  [80.         47.72738733]
#  [89.         48.50670869]
#  [87.         48.33352616]
#  [81.         47.81397859]
#  [92.         48.76648247]
#  [91.         48.67989121]
#  [20.         42.53191159]]
